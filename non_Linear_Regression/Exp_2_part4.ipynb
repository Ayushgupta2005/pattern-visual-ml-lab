# %% [markdown]
# **Experiment No. 2**
#
# **Part 4 : Non-Linear Regression using Machine Learning Libraries**
#
# ## Dataset Description
#
# The dataset used in this experiment is **Ice Cream Selling Data**.
# It contains temperature values and corresponding ice cream sales values.
# The dataset is used to study the non-linear relationship between temperature and ice cream sales using machine learning libraries for curve fitting and regression analysis.

# %%
# Importing numpy for numerical computations
import numpy as np

# Importing pandas for data handling and analysis
import pandas as pd

# Importing matplotlib for data visualization
import matplotlib.pyplot as plt

# Importing Linear Regression model
from sklearn.linear_model import LinearRegression

# Importing PolynomialFeatures for non-linear feature transformation
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Loading Dataset

# %%
# Loading the Ice Cream Selling dataset from CSV file
df = pd.read_csv("Ice_cream_selling_data.csv")

# Displaying the first 5 rows of the dataset
print(df.head())
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
# Extracting input feature (Temperature)
X = df.iloc[:, 0].values.reshape(-1, 1)

# Extracting target variable (Ice Cream Sales)
y = df.iloc[:, 1].values

# %%
# Visualizing the dataset using scatter plot
plt.scatter(X, y)

# Labeling x-axis
plt.xlabel("Temperature")

# Labeling y-axis
plt.ylabel("Ice Cream Sales")

# Adding title to the graph
plt.title("Data Visualization")

# Displaying the plot
plt.show()

# %% [markdown]
# ## Observation
#
# - Data is not a straight line
# - It has a curve pattern
#
# So linear regression will not fit properly

# %%
# Creating the Linear Regression model
lin_model = LinearRegression()

# Training the model on the dataset
lin_model.fit(X, y)

# Predicting output values using Linear Regression
y_lin_pred = lin_model.predict(X)

# Plotting original data points
plt.scatter(X, y)

# Plotting linear regression line
plt.plot(X, y_lin_pred, color='red')

# Adding title to the graph
plt.title("Linear Regression (Bad Fit)")

# Displaying the plot
plt.show()

# %% [markdown]
# ## Why Linear Regression Fails
#
# - Linear regression tries to fit a straight line
# - But data is curved
# - So model underfits
#
# This is called underfitting

# %%
# Creating polynomial features of degree 2
poly = PolynomialFeatures(degree=2)

# Transforming input data into polynomial features
X_poly = poly.fit_transform(X)

# %%
# Creating the Polynomial Regression model
poly_model = LinearRegression()

# Training the model using polynomial features
poly_model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Predicting output values using the trained Polynomial Regression model
y_poly_pred = poly_model.predict(X_poly)

# %%
# Plotting original data points
plt.scatter(X, y)

# Creating smooth input values for curve plotting
X_grid = np.linspace(min(X), max(X), 100).reshape(-1, 1)

# Transforming grid values into polynomial features
X_grid_poly = poly.transform(X_grid)

# Plotting polynomial regression fitted curve
plt.plot(X_grid, poly_model.predict(X_grid_poly), color='green')

# Adding title to the graph
plt.title("Polynomial Regression (Good Fit)")

# Displaying the plot
plt.show()

# %% [markdown]
# ## Result
#
# The Polynomial Regression model was successfully implemented using machine learning libraries on the Ice Cream Selling dataset. The fitted polynomial curve accurately captured the non-linear relationship between temperature and ice cream sales. Compared to Linear Regression, Polynomial Regression provided a better fit to the data.
#
# ## Conclusion
#
# In this experiment, non-linear regression was performed using Polynomial Regression with machine learning libraries. The experiment demonstrated that Polynomial Regression is more suitable for datasets having curved relationships between variables. The fitted curve successfully modeled the non-linear trend in the dataset and improved the overall regression performance.
